# %% [markdown]
# # PredNet training
# This notebook contains code to train a [predictive coding network](https://github.com/thefonseca/predictive-coding) on the [Moments in Time dataset](http://moments.csail.mit.edu) (dataset is not provided here).

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !wget -O prednet.zip https://github.com/thefonseca/predictive-coding/archive/master.zip && unzip -q prednet.zip
# Out:
# --2019-06-17 20:59:01--  https://github.com/thefonseca/predictive-coding/archive/master.zip
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/thefonseca/predictive-coding/zip/master [following]
# --2019-06-17 20:59:02--  https://codeload.github.com/thefonseca/predictive-coding/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘prednet.zip’
#
# prednet.zip             [     <=>            ]  26.09M  18.7MB/s    in 1.4s
#
# 2019-06-17 20:59:03 (18.7 MB/s) - ‘prednet.zip’ saved [27355460]

# %% [markdown]
# ## Get PredNet pre-trained models

# %%
# !cp -r gdrive/My\ Drive/prednet-models /content/

# %% [markdown]
# ## Get video data

# %%
# !cp gdrive/My\ Drive/moments_30classes.zip .

# %%
# !unzip -q moments_30classes.zip
# Out:
# replace content/predictive-coding-master/datasets/moments_video_frames/training/climbing/yt-pNsY-4I3oVs_108__frame_087.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !cp -r content/predictive-coding-master/datasets/moments_video_frames predictive-coding-master/datasets/

# %% [markdown]
# ## Extract frames from raw videos

# %%
#!wget https://s3.amazonaws.com/models.fonseca.com/moments_lesson1.zip && unzip -q moments_lesson1.zip
#!wget -O moments_mini.zip https://s3.amazonaws.com/models.fonseca.com/Moments_in_Time_Mini.zip # && unzip -q moments_mini.zip
#!cp gdrive/My\ Drive/Moments_in_Time_Mini.zip .
# unzip could not extract the file, so...
#!7z x Moments_in_Time_Mini.zip -aos -o./moments_mini
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 10071720513 bytes (9606 MiB)
#
# Extracting archive: Moments_in_Time_Mini.zip
#  99% 220672 Open
# ERRORS:
# Unexpected end of archive
#
# --
# Path = Moments_in_Time_Mini.zip
# Type = zip
# ERRORS:
# Unexpected end of archive
# Physical Size = 10071720513
#
# ERROR: Can not open output file : File name too long : ./moments_mini/__MACOSX/Moments_in_Time_Mini/training/bulldozing/._vb-mountain-clearing-dead-burned-cedar-trees-bulldozer-bulldozers-clears-dead-burned-trees-mountain-bulldozer-clearing-burned-dead-trees-from-mountain-by-dragging-chain-between-two-machines-trees-killed-and-destroyed-by-devastating-wildfire-6tkvnkh_13.mp4
#  99% 219955 - Moments_in_Time_Mini/validat . 3-video-id1B03534_0012_1.mp4
# Sub items Errors: 1
#
# ...

# %%
#!python predictive-coding-master/datasets/moments_frames.py predictive-coding-master/datasets/moments_lesson1 predictive-coding-master/datasets/moments_video_frames
# !python predictive-coding-master/datasets/moments_frames.py moments_mini/Moments_in_Time_Mini/ predictive-coding-master/datasets/moments_video_frames \
--categories barking cooking driving juggling photographing biting climbing running sleeping walking \
arresting ascending assembling attacking baking barbecuing bending bicycling boating boiling \
bouncing boxing brushing bubbling bulldozing burning camping carrying carving catching
# celebrating chasing cheering chewing chopping clapping cleaning climbing
# Out:
# Processing training set: 100% 15000/15000 [35:25<00:00,  6.08it/s]
# Processing validation set: 100% 1462/1462 [03:29<00:00,  6.96it/s]

# %%
# !zip -qr moments_30classes.zip /content/predictive-coding-master/datasets/moments_video_frames

# %%
# !cp /content/moments_30classes.zip gdrive/My\ Drive/

# %% [markdown]
# ## Training on video data

# %%
# a lazy fix
# !mv settings.py predictive-coding-master/models/prednet/

# %%
# !cd predictive-coding-master/models/prednet && python train.py prednet_random__moments__model --task 6_layers
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0618 14:35:13.645500 140207434663808 deprecation_wrapper.py:119] From train.py:27: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0618 14:35:13.645805 140207434663808 deprecation_wrapper.py:119] From train.py:28: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0618 14:35:13.657673 140207434663808 deprecation_wrapper.py:119] From train.py:29: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0618 14:35:13.657826 140207434663808 deprecation_wrapper.py:119] From train.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2019-06-18 14:35:13.662392: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...

# %%
# !cp -r predictive-coding-master/models/prednet gdrive/My\ Drive/prednet-models-$(date +%Y-%m-%dT%H:%M:%S)

# %% [markdown]
# ## Fine-tuning on Algonauts dataset

# %%
# after updloading the .zip ...
# !unzip -q algonauts.zip && mv ./results/ ./algonauts/prednet/models

# %%
# !wget https://s3.amazonaws.com/models.fonseca.com/algonautsChallenge2019.zip && unzip -q algonautsChallenge2019.zip && mv algonautsChallenge2019/*_Data ./algonauts/
# Out:
# --2019-05-30 20:06:41--  https://s3.amazonaws.com/models.fonseca.com/algonautsChallenge2019.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.170.21
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.170.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104503643 (100M) [application/zip]
# Saving to: ‘algonautsChallenge2019.zip’
#
# algonautsChallenge2 100%[===================>]  99.66M  52.7MB/s    in 1.9s
#
# 2019-05-30 20:06:43 (52.7 MB/s) - ‘algonautsChallenge2019.zip’ saved [104503643/104503643]

# %%
# !mv *.py ./algonauts/prednet/

# %%
# !cd algonauts/prednet/ && python train.py prednet_random__algonauts --train-dir ../Training_Data/118_Image_Set/ --val-dir ../Training_Data/92_Image_Set/
# Out:
# Using TensorFlow backend.
# 2019-05-30 20:30:57.943885: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-30 20:30:57.944297: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x327f1e0 executing computations on platform Host. Devices:
# 2019-05-30 20:30:57.944334: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-30 20:30:58.119974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-30 20:30:58.120446: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x327edc0 executing computations on platform CUDA. Devices:
# 2019-05-30 20:30:58.120475: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...
